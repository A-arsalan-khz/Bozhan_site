# %% [markdown]
# متد  پست برای گرفتن اطلاعات یک فرم هستش

# %%
<form method="POST">
  <input type="text" name="username">
  <input type="password" name="password">
  <button type="submit">ارسال</button>
</form>

def login_view(request):
    if request.method == 'POST':
        username = request.POST.get('username')
        password = request.POST.get('password')
        return HttpResponse(f"نام کاربری: {username} - رمز: {password}")

# %% [markdown]
# <div dir='rtl'>
#  query_params چیه؟ به زبان ساده
# وقتی کاربر یا کلاینت (مثلاً مرورگر یا Postman) یک درخواست (Request) به سرور می‌فرسته، می‌تونه اطلاعاتی داخل URL قرار بده — به این اطلاعات می‌گیم:
#
# Query Parameters (پارامترهای پرس‌و‌جو یا فیلتر)
# </div>

# %%
from IPython.display import Image

Image("Screenshot (839).png")

# %%
session authentication == defualt admin
